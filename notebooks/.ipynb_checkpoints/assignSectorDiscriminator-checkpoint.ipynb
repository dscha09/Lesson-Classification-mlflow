# %%
import pandas as pd
import re

# %% [markdown]
# # Old Data

# %%
df = pd.read_excel("../../data/sentences-20200407.xlsx")
print(len(df))
print(df.columns)
# Out:
# 55368
# Index(['Unnamed: 0', 'Countries', 'Download Link', 'File Names', 'Lesson Type',
#        'Month', 'Project Number', 'Sectors', 'Themes', 'Title', 'Year',
#        'annotatedBy', 'annotationStatus', 'annotationSummary',
#        'annotationTitle', 'dataSource', 'id', 'isLesson', 'lastAnnotated',
#        'paragraph', 'source', 'reference_id', 'Modalities',
#        'machine generated', 'source_lesson', 'related_lessons',
#        'Lesson Strength', 'topic', 'topTopics'],
#       dtype='object')

# %%
for index, row in df.iterrows():
    if(row['Sectors'] == "['Multisector']"):
        df.at[index, 'Modalities'] = "['Project loan']"
        print(df.at[index, 'id'])
        print(df.at[index, 'Modalities'])
# Out:
# 7110
# ['Project loan']
# 7111
# ['Project loan']
# 7112
# ['Project loan']
# 7113
# ['Project loan']
# 35447
# ['Project loan']
# 35448
# ['Project loan']
# 35449
# ['Project loan']
# 35450
# ['Project loan']
# 35451
# ['Project loan']
# 35452
# ['Project loan']
# 35453
# ['Project loan']
# 35454
# ['Project loan']
# 35455
# ['Project loan']
# 35456
# ['Project loan']
# 35457
# ['Project loan']
# 35458
# ['Project loan']
# 35459
# ['Project loan']
# 35460
# ['Project loan']
# 35461
# ['Project loan']
# 35462
# ['Project loan']
# 35463
# ['Project loan']
# 35464
# ['Project loan']
# 35465
# ['Project loan']
# 35466
# ['Project loan']
# 35467
# ['Project loan']
# 35468
# ['Project loan']
# 35469
# ['Project loan']
# 35470
# ['Project loan']
# 35471
# ['Project loan']
# 35472
# ['Project loan']
# 35473
# ['Project loan']
# 35474
# ['Project loan']
# 35475
# ['Project loan']
# 35476
# ['Project loan']
# 35477
# ['Project loan']
# 35478
# ['Project loan']
# 35479
# ['Project loan']
# ...

# %%
df.to_excel('../../data/sentences-20200413.xlsx')
