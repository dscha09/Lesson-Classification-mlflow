# %%
import pickle
import pandas as pd

# %% [markdown]
# # Integrate classifications and summaries

# %%
df = pd.read_excel('../data/merged_lessons_forecasted_data_reindex_20200225.xlsx')
dfClassificationsSummaries = pd.read_csv('../data/eva_forecast_02_21_2020.csv')

# %%
print(df.columns)
print(dfClassificationsSummaries.columns)
# Out:
# Index(['Unnamed: 0', 'Countries', 'Download Link', 'File Names', 'Lesson Type',
#        'Month', 'Project Number', 'Sectors', 'Themes', 'Title', 'Year',
#        'annotatedBy', 'annotationStatus', 'annotationSummary',
#        'annotationTitle', 'dataSource', 'id', 'isLesson', 'lastAnnotated',
#        'machine generated', 'paragraph', 'source', 'reference_id',
#        'related_lessons', 'Modalities', 'Lesson Strength', 'topic',
#        'topTopics'],
#       dtype='object')
# Index(['Unnamed: 0', 'paragraph', 'reference_id', 'project_number',
#        'lesson_num', 'machine-generated'],
#       dtype='object')

# %%
# dfClassificationsSummaries = dfClassificationsSummaries.rename(columns={"source_lesson": "id"})

# %%
merged = pd.merge(left=df, right=dfClassificationsSummaries, how='left', left_on='id', right_on='reference_id')

# %%
# merged = merged.drop(columns=['Unnamed: 0_x', 
#                               'Unnamed: 0_y', 
#                               'paragraph_y', 
#                               'reference_id_y', 
#                               'machine generated',
#                               'lesson_num',
#                               'project_number',
#                              ])
merged = merged.rename(columns={"machine-generated": "machine generated"})
merged = merged.rename(columns={"reference_id_x": "reference_id"})

# %%
print(merged.columns)
# Out:
# Index(['Countries', 'Download Link', 'File Names', 'Lesson Type', 'Month',
#        'Project Number', 'Sectors', 'Themes', 'Title', 'Year', 'annotatedBy',
#        'annotationStatus', 'annotationSummary', 'annotationTitle',
#        'dataSource', 'id', 'isLesson', 'lastAnnotated', 'paragraph_x',
#        'source', 'reference_id', 'related_lessons', 'Modalities',
#        'Lesson Strength', 'topic', 'topTopics', 'machine generated'],
#       dtype='object')

# %%
merged['isLessonOld'] = merged['isLesson']
merged['isLesson'] = False
for index, row in merged.iterrows():
    if(merged.at[index, 'machine generated'] == merged.at[index, 'machine generated']):
        merged.at[index, 'isLesson'] = True

# %%
merged.to_excel('../data/../data/merged_lessons_forecasted_data_reindex_20200225.xlsx')

# %% [markdown]
# # Integrate related lessons

# %%
with open('../../data/related_lessons_agg (2).pkl', 'rb') as f:
    dfRelatedLessons = pickle.load(f)
df = pd.read_excel('../data/../merged_lessons_forecasted_data_reindex_20200227.xlsx')

# %%
dfRelatedLessons['related_lessons']
# Out:
# 0         [32710, 32738, 32724, 32714, 7941]
# 1        [16711, 45808, 35009, 35418, 35047]
# 2          [7969, 7961, 57488, 29411, 37846]
# 3        [18366, 35418, 35416, 45808, 18393]
# 4         [7966, 57961, 17850, 11542, 17302]
# 5        [32724, 32738, 32714, 47073, 47171]
# 6         [46482, 21234, 20529, 9243, 32415]
# 7        [32738, 32724, 32714, 32710, 32704]
# 8        [13280, 35454, 27677, 13279, 16007]
# 9             [7969, 7968, 7938, 7963, 7964]
# 10         [7964, 7968, 16181, 53673, 16200]
# 11         [7963, 16181, 53673, 16200, 7968]
# 12        [7940, 37705, 56276, 53944, 46386]
# 13          [7961, 7963, 7964, 53673, 16181]
# 14           [7961, 7938, 7941, 7968, 32738]
# 15        [25616, 55725, 44713, 24570, 7980]
# 16       [11879, 57153, 57845, 50955, 34185]
# 17       [11622, 44713, 14140, 44259, 12140]
# 18       [21516, 18534, 12140, 26827, 24408]
# 19       [18339, 36972, 28186, 19392, 52895]
# 20        [51837, 18461, 7973, 26082, 39585]
# 21        [8041, 36923, 16412, 22895, 22532]
# 22         [8041, 8037, 50997, 51028, 45334]
# 23        [8036, 10245, 28919, 23400, 36594]
# 24         [8036, 8033, 50997, 45334, 51028]
# 25        [32070, 8037, 15752, 31226, 45279]
# 26       [37738, 37740, 37739, 45182, 33235]
# 27       [10241, 48347, 33587, 33588, 49681]
# 28            [8121, 8115, 8125, 8114, 8120]
# 29          [8116, 8120, 8114, 40062, 50733]
#                         ...
# 13213    [57924, 57942, 31883, 57941, 32249]
# 13214    [33172, 30402, 20014, 30407, 56319]
# 13215    [57956, 57955, 34003, 34006, 18042]
# 13216    [57954, 34003, 18042, 57956, 34006]
# 13217    [57962, 57954, 57955, 34003, 57971]
# 13218     [15522, 39600, 57955, 27717, 7939]
# 13219    [57981, 47989, 12380, 15161, 57980]
# 13220    [18042, 34006, 15960, 57991, 57955]
# 13221    [57971, 57956, 57972, 57991, 57955]
# 13222    [57971, 57962, 57972, 34247, 57991]
# 13223    [31433, 15156, 57955, 57954, 34003]
# 13224    [57962, 57956, 57972, 57963, 57991]
# 13225    [57962, 57971, 57956, 25540, 53869]
# 13226    [34457, 57979, 41758, 28952, 34003]
# 13227     [35511, 51067, 8503, 38699, 17120]
# 13228    [48839, 10275, 15409, 18025, 25451]
# 13229    [10962, 34003, 34005, 18042, 28962]
# 13230    [57958, 47989, 57981, 15161, 12380]
# 13231    [57958, 47989, 12380, 13156, 39889]
# 13232    [57955, 34005, 34003, 57954, 18042]
# 13233    [31782, 23930, 12390, 20980, 55457]
# 13234    [57962, 57956, 57955, 18042, 57971]
# 13235    [42343, 58002, 42373, 42377, 42346]
# 13236    [57995, 37524, 17661, 31460, 15954]
# 13237    [37537, 39433, 58010, 19946, 19928]
# 13238    [37538, 39433, 58009, 19928, 37537]
# 13239    [43446, 58021, 43424, 39433, 58010]
# 13240    [58017, 43424, 14020, 43446, 18520]
# 13241    [15479, 42349, 42343, 57068, 42369]
# 13242    [42343, 42346, 57995, 21817, 54220]
# Name: related_lessons, Length: 13243, dtype: object

# %%
merged = pd.merge(left=df, right=dfRelatedLessons, how='left', left_on='id', right_on='id')

# %%
len(merged)
# Out:
# 65614

# %%
merged.to_excel('../data/../data/merged_lessons_forecasted_data_reindex_20200228.xlsx')

# %% [markdown]
# # Integrate topics and lesson strengths

# %%
df = pd.read_excel('../data/merged_lessons_forecasted_data_reindex_20200225.xlsx')
dfLessonStrengths = pd.read_excel('../data/paragraph_topics_lesson_strengths_20200226.xlsx')

# %%
# df = df.drop(columns=['topic_x'])
# df = df.drop(columns=['Unnamed: 0_y.1'])
# df = df.drop(columns=['Lesson Strength_x'])
# df = df.drop(columns=['topic_y'])
# df = df.drop(columns=['Unnamed: 0.1.1.1'])

print(df.columns)
print(dfLessonStrengths.columns)
# Out:
# Index(['Unnamed: 0', 'Countries', 'Download Link', 'File Names', 'Lesson Type',
#        'Month', 'Project Number', 'Sectors', 'Themes', 'Title', 'Year',
#        'annotatedBy', 'annotationStatus', 'annotationSummary',
#        'annotationTitle', 'dataSource', 'id', 'isLesson', 'lastAnnotated',
#        'paragraph', 'source', 'reference_id', 'related_lessons', 'Modalities',
#        'Lesson Strength', 'topic', 'topTopics', 'machine generated'],
#       dtype='object')
# Index(['Unnamed: 0', 'id', 'Lesson Strength', 'topic', 'topTopics'], dtype='object')

# %%
df = df.drop(columns=['Unnamed: 0', 'Lesson Strength', 'topic', 'topTopics'])
dfLessonStrengths = dfLessonStrengths.drop(columns=['Unnamed: 0'])

# %%
print(df.columns)
# Out:
# Index(['Countries', 'Download Link', 'File Names', 'Lesson Type', 'Month',
#        'Project Number', 'Sectors', 'Themes', 'Title', 'Year', 'annotatedBy',
#        'annotationStatus', 'annotationSummary', 'annotationTitle',
#        'dataSource', 'id', 'isLesson', 'lastAnnotated', 'paragraph', 'source',
#        'reference_id', 'related_lessons', 'Modalities', 'machine generated'],
#       dtype='object')

# %%
merged = pd.merge(left=df, right=dfLessonStrengths, how='left', left_on='id', right_on='id')

# %%
merged.columns
# Out:
# Index(['Countries', 'Download Link', 'File Names', 'Lesson Type', 'Month',
#        'Project Number', 'Sectors', 'Themes', 'Title', 'Year', 'annotatedBy',
#        'annotationStatus', 'annotationSummary', 'annotationTitle',
#        'dataSource', 'id', 'isLesson', 'lastAnnotated', 'paragraph', 'source',
#        'reference_id', 'related_lessons', 'Modalities', 'machine generated',
#        'Lesson Strength', 'topic', 'topTopics'],
#       dtype='object')

# %%
merged.to_excel('../data/merged_lessons_forecasted_data_reindex_20200226.xlsx')

# %% [markdown]
# # Integrate modality

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Countries', 'Download Link', 'File Names', 'Lesson Type',
#        'Month', 'Project Number', 'Sectors', 'Themes', 'Title', 'Year',
#        'annotatedBy', 'annotationStatus', 'annotationSummary',
#        'annotationTitle', 'dataSource', 'id', 'isLesson', 'lastAnnotated',
#        'machine generated', 'paragraph', 'source', 'reference_id',
#        'related_lessons', 'Lesson Strength', 'topic', 'topTopics'],
#       dtype='object')

# %%
df = pd.read_excel('../data/merged_lessons_forecasted_data_reindex_20200226.xlsx')
PCRDataFileName = '../data/pcrs_2020-02-25.xlsx'
PCRsData = pd.read_excel(PCRDataFileName)

# %%
print(PCRsData['UNQ_MODALITY_FR_DUMP'].unique())
# Out:
# ["{'MFF-Facility (Loan)'}" "{'Project loan'}" "{'MFF-Tranche (Loan)'}"
#  "{'Sector loan'}" "{'Project grant'}"
#  "{'Programmatic Approach Policy-Based Lending (Grant)'}"
#  "{'Program loan'}"
#  "{'Programmatic Approach Policy-Based Lending (Loan)'}"
#  "{'Program grant'}" 'set()' "{'Special assistance loan'}"
#  "{'Development financing institution (DFI)'}" "{'SDP - Program loan'}"
#  "{'Credit line (Loan)'}"
#  "{'Countercyclical Support Facility Lending (Loan)'}"
#  "{'Stand-Alone Policy-Based Lending (Grant)'}" "{'SDP - Project loan'}"
#  "{'Multiproject loan'}" "{'SDP - Program grant'}" "{'Sector grant'}"
#  "{'Capacity development technical assistance'}" "{'TA loan'}"
#  "{'SDP - Sector loan'}" "{'SDP - Credit line (Loan)'}"
#  "{'Project preparatory technical assistance'}"]

# %%
df['Modalities'] = ""
modalities = []
for index, row in df.iterrows():
    if(PCRsData[PCRsData['File Names']==df.at[index, 'File Names']].index.values):
        PCRsDataIndex = PCRsData[PCRsData['File Names']==df.at[index, 'File Names']].index.values[0]
        if(PCRsData.at[PCRsDataIndex, 'UNQ_MODALITY_FR_DUMP'] == 'set()'):
            modalities.append([])
        else:
            print([PCRsData.at[PCRsDataIndex, 'UNQ_MODALITY_FR_DUMP'][2:-2]])
            modalities.append([PCRsData.at[PCRsDataIndex, 'UNQ_MODALITY_FR_DUMP'][2:-2]])
    else:
        modalities.append([])
df['Modalities'] = modalities
# Out:
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Programmatic Approach Policy-Based Lending (Grant)']
# ['Programmatic Approach Policy-Based Lending (Grant)']
# ['Programmatic Approach Policy-Based Lending (Grant)']
# ['Programmatic Approach Policy-Based Lending (Grant)']
# ['Programmatic Approach Policy-Based Lending (Grant)']
# ['Programmatic Approach Policy-Based Lending (Grant)']
# ['Programmatic Approach Policy-Based Lending (Grant)']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Development financing institution (DFI)']
# ['Development financing institution (DFI)']
# ['Development financing institution (DFI)']
# ['Development financing institution (DFI)']
# ['Development financing institution (DFI)']
# ['Development financing institution (DFI)']
# ['Development financing institution (DFI)']
# ['Development financing institution (DFI)']
# ['Development financing institution (DFI)']
# ['Development financing institution (DFI)']
# ['Development financing institution (DFI)']
# ['Development financing institution (DFI)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['Special assistance loan']
# ['Special assistance loan']
# ['Special assistance loan']
# ['Special assistance loan']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Countercyclical Support Facility Lending (Loan)']
# ['Countercyclical Support Facility Lending (Loan)']
# ['Countercyclical Support Facility Lending (Loan)']
# ['Countercyclical Support Facility Lending (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['Stand-Alone Policy-Based Lending (Grant)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Multiproject loan']
# ['Multiproject loan']
# ['Multiproject loan']
# ['Multiproject loan']
# ['Multiproject loan']
# ['Multiproject loan']
# ['Multiproject loan']
# ['Multiproject loan']
# ['Multiproject loan']
# ['Multiproject loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['MFF-Facility (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Sector loan']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Program grant']
# ['SDP - Program grant']
# ['SDP - Program grant']
# ['SDP - Program grant']
# ['SDP - Program grant']
# ['SDP - Program grant']
# ['SDP - Program grant']
# ['SDP - Program grant']
# ['SDP - Program grant']
# ['SDP - Program grant']
# ['SDP - Program grant']
# ['SDP - Program grant']
# ['Project grant']
# ['Project grant']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Special assistance loan']
# ['Special assistance loan']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Programmatic Approach Policy-Based Lending (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Sector grant']
# ['Sector grant']
# ['Sector grant']
# ['Sector grant']
# ['Sector grant']
# ['Sector grant']
# ['Sector grant']
# ['Sector grant']
# ['Sector grant']
# ['Sector grant']
# ['Sector grant']
# ['Sector grant']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Credit line (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Project grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Program grant']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['TA loan']
# ['TA loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['MFF-Tranche (Loan)']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ...
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Project loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['SDP - Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Project loan']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Project loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Sector loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['SDP - Program loan']
# ['Capacity development technical assistance']
# ['Capacity development technical assistance']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['Project loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['TA loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project preparatory technical assistance']
# ['Project loan']
# ['Program loan']
# ['Program loan']
# ['Program loan']

# %%
# PCRsData.columns

# %%
df.to_excel('../data/merged_lessons_forecasted_data_reindex_20200226.xlsx')

# %%
df['Modalities'].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-163-65f661df7820> in <module>
# ----> 1 df['Modalities'].unique()
#
# ~/Documents/ADB-CognitiveSearch-venv/lib/python3.7/site-packages/pandas/core/series.py in unique(self)
#    1665         Categories (3, object): [a < b < c]
#    1666         """
# -> 1667         result = super(Series, self).unique()
#    1668         return result
#    1669
#
# ~/Documents/ADB-CognitiveSearch-venv/lib/python3.7/site-packages/pandas/core/base.py in unique(self)
#    1312         else:
#    1313             from pandas.core.algorithms import unique1d
# -> 1314             result = unique1d(values)
#    1315
#    1316         return result
#
# ~/Documents/ADB-CognitiveSearch-venv/lib/python3.7/site-packages/pandas/core/algorithms.py in unique(values)
#     360
#     361     table = htable(len(values))
# --> 362     uniques = table.unique(values)
#     363     uniques = _reconstruct_data(uniques, dtype, original)
#     364     return uniques
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
