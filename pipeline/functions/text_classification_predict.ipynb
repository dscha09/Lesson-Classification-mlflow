# %%
from fastai.text import load_learner
from pathlib import Path

ROOT_PATH = r"C:\Users\Test Machine\Documents\ADB-CognitiveSearch-ML\pipeline\functions\models"

learn = load_learner(Path(ROOT_PATH), "lesson_classif-04-05-2020_11-05-30_PM.pkl")

# %%
learn
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (0 items)
# x: TextList
#
# y: CategoryList
#
# Path: C:\Users\Test Machine\Documents\ADB-CognitiveSearch-ML\pipeline\functions\models;
#
# Valid: LabelList (0 items)
# x: TextList
#
# y: CategoryList
#
# Path: C:\Users\Test Machine\Documents\ADB-CognitiveSearch-ML\pipeline\functions\models;
#
# Test: None, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(7048, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(7048, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=2, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x0000021560DC6708>, Precision(average='binary', pos_label=1, eps=1e-09), Recall(average='binary', pos_label=1, eps=1e-09)], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=WindowsPath('C:/Users/Test Machine/Documents/ADB-CognitiveSearch-ML/pipeline/functions/models'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: ...
# alpha: 2.0
# beta: 1.0, MixedPrecision
# learn: ...
# loss_scale: 65536.0
# max_noskip: 1000
# dynamic: True
# clip: None
# flat_master: False
# max_scale: 16777216
# loss_fp32: True], layer_groups=[Sequential(
#   (0): Embedding(7048, 400, padding_idx=1)
#   (1): Embedding(7048, 400, padding_idx=1)
#   (2): LSTM(400, 1152, batch_first=True)
#   (3): LSTM(1152, 1152, batch_first=True)
#   (4): LSTM(1152, 400, batch_first=True)
#   (5): RNNDropout()
#   (6): RNNDropout()
#   (7): RNNDropout()
#   (8): RNNDropout()
#   (9): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): Dropout(p=0.2, inplace=False)
#   (11): Linear(in_features=1200, out_features=50, bias=True)
#   (12): ReLU(inplace=True)
#   (13): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): Dropout(p=0.1, inplace=False)
#   (15): Linear(in_features=50, out_features=2, bias=True)
# )], add_time=True, silent=False)

# %%
import pandas as pd

# %%
data_dir = "./data/sample_data"
train_lesson_par_df = pd.read_csv(data_dir + "/train_lesson_classif.csv")
test_lesson_par_df = pd.read_csv(data_dir + "/test_lesson_classif.csv")
to_predict_par_df = pd.read_csv(data_dir + "/to_predict_lesson_paragraphs.csv")

# %%
def plot_confusion_matrix(y_actual, y_pred):
    data = {
            'y_Actual': y_actual,
            'y_Predicted': y_pred
    }
    
    print(f"Precision={precision_score(y_actual,y_pred, average='weighted')}")
    print(f"Recall={recall_score(y_actual,y_pred, average='weighted')}")
    print(f"Accuracy={accuracy_score(y_actual, y_pred)}")

    df = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
    confusion_matrix = pd.crosstab(df['y_Actual'], df['y_Predicted'], rownames=['Actual'], colnames=['Predicted'], margins = True)
    confusion_matrix = confusion_matrix.iloc[:-1,:-1]

    sns.heatmap(confusion_matrix, annot=True)

# %%
from fastai.text import *

forecasts = []
actual = test_lesson_par_df.is_lesson.values

for p in test_lesson_par_df.paragraph: 
#     print(learn_classif.predict(p))
    forecasts.append(try_int(learn.predict(p)[0]))
plot_confusion_matrix(actual, forecasts)
# Out:
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# ...
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# C:\Users\Test Machine\Anaconda3\lib\site-packages\fastai\torch_core.py:83: UserWarning: Tensor is int32: upgrading to int64; for better performance use int64 input
#   warn('Tensor is int32: upgrading to int64; for better performance use int64 input')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-52d2b70ac253> in <module>
#       7 #     print(learn_classif.predict(p))
#       8     forecasts.append(try_int(learn.predict(p)[0]))
# ----> 9 plot_confusion_matrix(actual, forecasts)
#
# <ipython-input-17-1a67f0a6bc94> in plot_confusion_matrix(y_actual, y_pred)
#       5     }
#       6
# ----> 7     print(f"Precision={precision_score(y_actual,y_pred, average='weighted')}")
#       8     print(f"Recall={recall_score(y_actual,y_pred, average='weighted')}")
#       9     print(f"Accuracy={accuracy_score(y_actual, y_pred)}")
#
# NameError: name 'precision_score' is not defined
